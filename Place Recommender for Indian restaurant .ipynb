# %% [markdown]
# # Capstone Project - Best Place to open an Indian Restaurant in New York

# %% [markdown]
# ## Introduction

# %% [markdown]
# A person wants to open an Indian restaurant in New York. The idea behind this project is that there may not be enough Indian restaurants in New York and it might present a great opportunity for this person who is based in New York. As Indian food is very similar to other Asian cuisines, this person is thinking of opening this restaurant in locations where Asian food is popular. With the purpose in mind, finding the location to open such a restaurant is one of the most important decisions for this person and I am creating a model to help the person in finding the best location to open the restaurant in New York.

# %% [markdown]
# ## Business Problem
# In New York, if someone wants to open a Indian restaurant, where should they consider opening it?

# %% [markdown]
# ## Data
# For model designing following data will be required:
#
# * List of neighborhoods in New York.
# * Latitude and Longitude of these neighborhoods.
# * Venue data related to Indian and Asian restaurants. This will help us find the best places that are most suitable to open a Indian restaurant.
#
#
# Following data sources will be needed to extract/generate the required information:
#
# * The information regarding the neighborhoods in New York and their corresponding latitude and longitude coordinates can be downloaded from the following link “https://geo.nyu.edu/catalog/nyu_2451_34572”.
# * Use geopy library to get the latitude and longitude values of New York City.
# * number of restaurants and their type and location in every neighborhood will be obtained using Foursquare API.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# Load and explore the data

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %% [markdown]
# #### Tranform the data into a *pandas* dataframe

# %% [markdown]
# The next task is essentially transforming this data of nested Python dictionaries into a *pandas* dataframe. So let's start by creating an empty dataframe.

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Then let's loop through the data and fill the dataframe one row at a time.

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# So let's slice the original dataframe and create a new dataframe of the Manhattan data.

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Manhattan.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>ny_explorer</em>, as shown below.

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.7896239, -73.9598939.

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# #### Let's explore the first neighborhood in our dataframe.

# %% [markdown]
# Get the neighborhood's name.

# %%
manhattan_data.loc[0, 'Neighborhood']
# Out:
# 'Marble Hill'

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = manhattan_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = manhattan_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = manhattan_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Marble Hill are 40.87655077879964, -73.91065965862981.

# %% [markdown]
# Let set the limit and radius for the foursquare api

# %%
LIMIT = 100
radius = 500

# %% [markdown]
# #### Let's create a function to repeat the same process to all the neighborhoods in Manhattan

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name'],
        v['venue']['id']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category',
                            'Id']
    
    return(nearby_venues)

# %% [markdown]
# #### Now run the above function on each neighborhood and create a new dataframe called *manhattan_venues*.

# %%
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %% [markdown]
# #### Let's check the size of the resulting dataframe

# %%
print(manhattan_venues.shape)
manhattan_venues.head()
# Out:
# (3327, 8)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude          Venue  \
# 0  Marble Hill              40.876551               -73.91066       Arturo's
# 1  Marble Hill              40.876551               -73.91066    Bikram Yoga
# 2  Marble Hill              40.876551               -73.91066  Tibbett Diner
# 3  Marble Hill              40.876551               -73.91066      Starbucks
# 4  Marble Hill              40.876551               -73.91066        Dunkin'
#
#    Venue Latitude  Venue Longitude Venue Category                        Id
# 0       40.874412       -73.910271    Pizza Place  4b4429abf964a52037f225e3
# 1       40.876844       -73.906204    Yoga Studio  4baf59e8f964a520a6f93be3
# 2       40.880404       -73.908937          Diner  4b79cc46f964a520c5122fe3
# 3       40.877531       -73.905582    Coffee Shop  55f81cd2498ee903149fcc64
# 4       40.877136       -73.906666     Donut Shop  4b5357adf964a520319827e3

# %% [markdown]
# So let's slice the original dataframe and create a new dataframe of the Indian and Asian Restaurants.

# %%
category = ['Indian Restaurant','Asian Restaurant']
manhattan_indian_restaurant = manhattan_venues[manhattan_venues['Venue Category'].isin(category)]

# %% [markdown]
# #### Now I will creat a map of New York with Indian and Asian restaurants superimposed on top.

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, Venue, neighborhood in zip(manhattan_indian_restaurant['Neighborhood Latitude'], manhattan_indian_restaurant['Neighborhood Longitude'], manhattan_indian_restaurant['Venue'], manhattan_indian_restaurant['Neighborhood']):
    label = '{}, {}'.format(neighborhood, Venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Let's create a function to get the ratings of all the Indian and Asian restaurants in New York

# %%
def getVenueRating(id):
    print(id)
    
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
        id,
        CLIENT_ID, 
        CLIENT_SECRET, 
         VERSION, 
        )
            
    # make the GET request
    result = requests.get(url).json()
    print(result)
    if(result["response"] == {}):
        rating = 'NA'
    else:
        rating = result["response"]['venue']['rating']
        
    return(rating)

# %% [markdown]
#  Now I will apply the above function on each resturant and add two new columns in dataframe called *Rating and Id*.

# %%
manhattan_indian_restaurant['Rating'] = manhattan_indian_restaurant['Id'].apply(getVenueRating)
# Out:
# 4b89ac72f964a520e94a32e3
# {'meta': {'code': 200, 'requestId': '5d90675c6001bc002bc4487b'}, 'response': {'venue': {'id': '4b89ac72f964a520e94a32e3', 'name': 'Ling Kee', 'contact': {}, 'location': {'address': '42 Canal St', 'crossStreet': 'Ludlow', 'lat': 40.714713, 'lng': -73.991538, 'labeledLatLngs': [{'label': 'display', 'lat': 40.714713, 'lng': -73.991538}], 'postalCode': '10002', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['42 Canal St (Ludlow)', 'New York, NY 10002', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/ling-kee/4b89ac72f964a520e94a32e3', 'categories': [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '56aa371be4b08b9a8d57350b', 'name': 'Food Stand', 'pluralName': 'Food Stands', 'shortName': 'Food Stand', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 12}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 22, 'groups': [{'type': 'others', 'count': 22, 'items': []}], 'summary': '22 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 32, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 20, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 20, 'items': [{'id': '5bd5fb5bb5cb76002cc657c3', 'createdAt': 1540750171, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/414403748_C4nJy5PGLwA0Gld0LV4vjRU2u6Sc1VWWgrvGAlcl87Y.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '414403748', 'firstName': 'Bradford', 'lastName': 'Toney', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/414403748_U5v-FaSi_Eks6LljZbDEIy4Q8EKaYDEvzgxIPy9XWB2VIp4W0pBXx4BB-dy470xJJ3Z_8Fmhn.jpg'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1267313778, 'tips': {'count': 12, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 12, 'items': [{'id': '511c0145e4b0b9ae1a2ad2ad', 'createdAt': 1360789829, 'text': 'Tried the spicy beef, chicken, and pork jerky. Pork is hands down the most tender and flavorful of them all! Worth the $18/lb price tag.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/511c0145e4b0b9ae1a2ad2ad', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '157095', 'firstName': 'Teresa', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/157095_eTYe-wrR_hnyBsLA6ZU5T0wnpXgFtb_iA8Lqun9xfDS5UhLpuvxv6HBATAliIg7Lcca42SpVo.jpg'}}, {'id': '21842926', 'firstName': 'Jenny', 'lastName': 'Lin', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/21842926-PJYO0KICRLVWQZZC.jpg'}}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '131139', 'firstName': 'Stephanie', 'lastName': 'Tan', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/131139_sYajLV9O_l_8nUhFeLbGGPFVoVHivwq2U8G232Zuyrl3jAjC2hHg1_NiRx2wl32cARruZMRTR.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/aq8DjR', 'timeZone': 'America/New_York', 'listed': {'count': 41, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 41, 'items': [{'id': '501ef46be4b067f6ad902ca9', 'name': 'USA NYC MAN Chinatown', 'description': "Manhattan's Chinatown & Little Italy.", 'ty ...
# 574f2ae0498ec2a700651b95
# {'meta': {'code': 200, 'requestId': '5d90675d8afbe0002daf707d'}, 'response': {'venue': {'id': '574f2ae0498ec2a700651b95', 'name': 'Simple', 'contact': {'phone': '6468708292', 'formattedPhone': '(646) 870-8292', 'twitter': 'simple109nyc', 'instagram': 'simple.nyc', 'facebook': '1114411211914045', 'facebookUsername': 'simple109nyc', 'facebookName': 'Simple NYC'}, 'location': {'address': '109 Eldridge St', 'crossStreet': 'btwn Broome & Grand St', 'lat': 40.71814514203096, 'lng': -73.99198775758143, 'labeledLatLngs': [{'label': 'display', 'lat': 40.71814514203096, 'lng': -73.99198775758143}], 'postalCode': '10002', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['109 Eldridge St (btwn Broome & Grand St)', 'New York, NY 10002', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/simple/574f2ae0498ec2a700651b95', 'categories': [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 46}, 'url': 'http://simple-nyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 162, 'groups': [{'type': 'others', 'count': 162, 'items': []}], 'summary': '162 Likes'}, 'dislike': False, 'ok': False, 'rating': 9.2, 'ratingColor': '00B551', 'ratingSignals': 211, 'delivery': {'id': '1008754', 'url': 'https://www.seamless.com/menu/simple-bento--poke-109-eldridge-st-new-york/1008754?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1008754', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://simple-nyc.com/menu/', 'mobileUrl': 'https://simple-nyc.com/menu/', 'externalUrl': 'https://simple-nyc.com/menu/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 99, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 99, 'items': [{'id': '5c89aa73f427de002cec647b', 'createdAt': 1552525939, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/41232526_hdmFx098qXMZgDTRmFkFXSkZ4_iBiNEX-N9VRdNjYV4.jpg', 'width': 1080, 'height': 1920, 'user': {'id': '41232526', 'firstName': 'Betty', 'lastName': 'Chung', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/O3PRYXTAJXR4ERI5.jpg'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Simple features East-Asian/Pacific Island foods and fare that pack both flavor and simplicity.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1464806112, 'tips': {'count': 46, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 46, 'items': [{'id': '587580efd25ded6a66f57ca9', 'createdAt': 1484095727, 'text': 'Huge, delicious poke bowls. Awesome vegetarian and vegan options - the sauce on the tofu was out of this world. Get with quinoa.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/587580efd25ded6a66f57ca9', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'id': '92038077', 'firstName': 'Thomas', 'lastName': 'Briggs', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/92038077_N1s-q0ZE_EDSM_4lm9P-yeVagStGayI_Cc__GH5S2oRje51La_yfdXqdXZradJ1AZdwA8yea0'}}]}], 'sum ...
# 4ae7876ef964a5201eac21e3
# {'meta': {'code': 200, 'requestId': '5d90675d598e64002cdc3c66'}, 'response': {'venue': {'id': '4ae7876ef964a5201eac21e3', 'name': 'Kismat Indian Restaurant', 'contact': {'phone': '2127958633', 'formattedPhone': '(212) 795-8633', 'twitter': 'kismatindian'}, 'location': {'address': '603 Fort Washington Ave', 'crossStreet': '187th St', 'lat': 40.855221723964846, 'lng': -73.93696683600031, 'labeledLatLngs': [{'label': 'display', 'lat': 40.855221723964846, 'lng': -73.93696683600031}], 'postalCode': '10040', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['603 Fort Washington Ave (187th St)', 'New York, NY 10040', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/kismat-indian-restaurant/4ae7876ef964a5201eac21e3', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 24}, 'url': 'http://kismatindianrestaurant-hub.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 45, 'groups': [{'type': 'others', 'count': 45, 'items': []}], 'summary': '45 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.8, 'ratingColor': 'C5DE35', 'ratingSignals': 70, 'delivery': {'id': '291797', 'url': 'https://www.seamless.com/menu/kismat-indian-cuisine-603-fort-washington-ave-new-york/291797?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=291797', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/kismat-indian-restaurant/4ae7876ef964a5201eac21e3/menu', 'mobileUrl': 'https://foursquare.com/v/4ae7876ef964a5201eac21e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 50, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 50, 'items': [{'id': '542aeef8498e40e206e5acd6', 'createdAt': 1412099832, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/94614245_FJErbef2X6bb9Zgd2pSxLySdQTWoHH_8ZI8UxcIfxXE.jpg', 'width': 700, 'height': 465, 'user': {'id': '94614245', 'firstName': 'Kismat Indian Restaurant', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/94614245-KIDFJXLQDMDGTRRX.png'}, 'type': 'venuePage', 'venue': {'id': '4ae7876ef964a5201eac21e3'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '94614245'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Kismat Indian Restaurant in New York, NY serves exceptionally fresh and aromatic Indian dishes. Come in and get some incredible Indian food!', 'storeId': '', 'page': {'user': {'id': '94614245', 'firstName': 'Kismat Indian Restaurant', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/94614245-KIDFJXLQDMDGTRRX.png'}, 'type': 'venuePage', 'venue': {'id': '4ae7876ef964a5201eac21e3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1256687470, 'tips': {'count': 24, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 24, 'items': [{'id': '4ae7885d70c603bb72b98eb4', 'createdAt': 1256687709, 'text': 'BEST Indian food anywhe ...
# 54c2bd96498eaf5142e3fe92
# {'meta': {'code': 200, 'requestId': '5d90675dad1789003864ac37'}, 'response': {'venue': {'id': '54c2bd96498eaf5142e3fe92', 'name': 'Clove Indian Restaurant & Bar', 'contact': {'phone': '6469186644', 'formattedPhone': '(646) 918-6644', 'twitter': 'cloveindian'}, 'location': {'address': '1592 Amsterdam Ave', 'crossStreet': 'btwn 139th St & 138th St', 'lat': 40.82128, 'lng': -73.95062, 'labeledLatLngs': [{'label': 'display', 'lat': 40.82128, 'lng': -73.95062}], 'postalCode': '10031', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1592 Amsterdam Ave (btwn 139th St & 138th St)', 'New York, NY 10031', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/clove-indian-restaurant--bar/54c2bd96498eaf5142e3fe92', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 15}, 'url': 'http://cloveindianrestaurant-hub.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 29, 'groups': [{'type': 'others', 'count': 29, 'items': []}], 'summary': '29 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 52, 'delivery': {'id': '308759', 'url': 'https://www.seamless.com/menu/clove-1592-amsterdam-ave-new-york/308759?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=308759', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 9, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 9, 'items': [{'id': '54ff149911d2fc312086c044', 'createdAt': 1426003097, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/122224155_qZDnKuStR3v2L_-ptkHOZNdDaIlmGvTPDqIeGk9N5t4.png', 'width': 300, 'height': 300, 'user': {'id': '122224155', 'firstName': 'Clove Indian Restaurant & Bar', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/122224155-PNTUABR3T1AF4EF4.png'}, 'type': 'venuePage', 'venue': {'id': '54c2bd96498eaf5142e3fe92'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '122224155'}, 'reasons': {'count': 0, 'items': []}, 'description': 'Clove Indian Restaurant and Bar in New York City offers delicious Indian Cuisine and a range of signature cocktails.', 'storeId': '', 'page': {'user': {'id': '122224155', 'firstName': 'Clove Indian Restaurant & Bar', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/122224155-PNTUABR3T1AF4EF4.png'}, 'type': 'venuePage', 'venue': {'id': '54c2bd96498eaf5142e3fe92'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1422048662, 'tips': {'count': 15, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 15, 'items': [{'id': '54c2be4c498ea6f7a30231f2', 'createdAt': 1422048844, 'text': 'Get your tandoori from the buffet with some beer & wine options. A bar is in the works for those that want a spicy happy hour. Prices are geared toward the collegiate budget. Dining is quite relaxed.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/54c2be4c498ea6f7a30231f2', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '407782671', 'firstName': ...
# 5914ff32b23dfa207eca38de
# {'meta': {'code': 200, 'requestId': '5d90675e531593002c86e32a'}, 'response': {'venue': {'id': '5914ff32b23dfa207eca38de', 'name': 'Mumbai Masala', 'contact': {'phone': '2123680100', 'formattedPhone': '(212) 368-0100'}, 'location': {'address': '1768 Amsterdam Ave', 'lat': 40.82686602760178, 'lng': -73.94648647401726, 'labeledLatLngs': [{'label': 'display', 'lat': 40.82686602760178, 'lng': -73.94648647401726}], 'postalCode': '10031', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1768 Amsterdam Ave', 'New York, NY 10031', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/mumbai-masala/5914ff32b23dfa207eca38de', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 6}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 13, 'groups': [{'type': 'others', 'count': 13, 'items': []}], 'summary': '13 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.4, 'ratingColor': 'C5DE35', 'ratingSignals': 21, 'delivery': {'id': '396563', 'url': 'https://www.seamless.com/menu/mumbai-masala-1768-amsterdam-ave-new-york/396563?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=396563', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 2, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 2, 'items': [{'id': '5d4ca08063755d00080319c8', 'createdAt': 1565302912, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4320083_6cZ3U3D8dgxP96e7ahbGmzdU2L8pkbdbe-P5w63Akks.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '4320083', 'firstName': 'jenni', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/KRRGCORNKJZ2WTGF.jpg'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1494548274, 'tips': {'count': 6, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 6, 'items': [{'id': '5c5b9a75598e64002cd84ecb', 'createdAt': 1549507189, 'text': 'The naan was incredibly fresh. Don’t pass it up!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c5b9a75598e64002cd84ecb', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '31651', 'firstName': 'Jared', 'lastName': 'Brodsky', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/YGYF1D244WPO1NT4.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2r7N3XQ', 'timeZone': 'America/New_York', 'listed': {'count': 3, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 3, 'items': [{'id': '590bf48c8a6f17198a650cae', 'name': 'Purvi Visits NYC', 'description': '', 'type': 'others', 'user': {'id': '137372850', 'firstName': 'Hillary', 'lastName': 'Khan', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/137372850/list/purvi-visits-nyc', 'canonicalUrl': 'https://foursquare.com/user/137372850/list/purvi-visits-nyc', 'createdAt': 1493955724, 'updatedAt': 1523668976, 'followers': {'count': 0}, 'listItems': {'coun ...
# 529d382a11d2dd5ef107e641
# {'meta': {'code': 200, 'requestId': '5d90675e2c201700372d3b8c'}, 'response': {'venue': {'id': '529d382a11d2dd5ef107e641', 'name': 'Chapati House - NYC', 'contact': {'phone': '2127497200', 'formattedPhone': '(212) 749-7200', 'twitter': 'chapatihousenyc'}, 'location': {'address': '3153 Broadway', 'crossStreet': 'Tiemann Pl.', 'lat': 40.81457249971737, 'lng': -73.95915381671377, 'labeledLatLngs': [{'label': 'display', 'lat': 40.81457249971737, 'lng': -73.95915381671377}], 'postalCode': '10027', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['3153 Broadway (Tiemann Pl.)', 'New York, NY 10027', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/chapati-house--nyc/529d382a11d2dd5ef107e641', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 18}, 'url': 'http://chapatihousenyc-hub.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 73, 'groups': [{'type': 'others', 'count': 73, 'items': []}], 'summary': '73 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.0, 'ratingColor': '73CF42', 'ratingSignals': 101, 'delivery': {'id': '288817', 'url': 'https://www.seamless.com/menu/chapati-house-3153-broadway-ave-new-york/288817?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=288817', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 25, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 25, 'items': [{'id': '54ecc93d498e6f9b0e99b2cb', 'createdAt': 1424804157, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/120966053_l4IMMtiwaPZfcTmGSIJ4UJuEHQ6hIXN7PCpr_oQPU7U.jpg', 'width': 913, 'height': 629, 'user': {'id': '120966053', 'firstName': 'Chapati House - NYC', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/120966053-Z2PHZNOXB02RLFRF.png'}, 'type': 'venuePage', 'venue': {'id': '529d382a11d2dd5ef107e641'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '120966053'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Chapati House specializes in delicious traditional Indian food that’s cooked slowly with care and served quickly with a smile.', 'page': {'user': {'id': '120966053', 'firstName': 'Chapati House - NYC', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/120966053-Z2PHZNOXB02RLFRF.png'}, 'type': 'venuePage', 'venue': {'id': '529d382a11d2dd5ef107e641'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1386035242, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '53a634c4498eaf17b2a6df8b', 'createdAt': 1403401412, 'text': 'love this place! Indian food, Chipotle-pick-your-main-&-toppings style!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/53a634c4498eaf17b2a6df8b', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '96516553', 'firstName': 'Pratyush', 'lastName': 'Nalam', 'gender': 'male', 'photo': {'prefix' ...
# 579fb23f498e7f9f1b7bd04c
# {'meta': {'code': 200, 'requestId': '5d90675e787dba002b6fef5c'}, 'response': {'venue': {'id': '579fb23f498e7f9f1b7bd04c', 'name': "Peng's Noodle Folk", 'contact': {'phone': '2123482878', 'formattedPhone': '(212) 348-2878', 'twitter': 'pengnoodle'}, 'location': {'address': '1659 1st Ave', 'crossStreet': 'btwn E 86th & E 87th St', 'lat': 40.77725764842952, 'lng': -73.94911007213871, 'labeledLatLngs': [{'label': 'display', 'lat': 40.77725764842952, 'lng': -73.94911007213871}], 'postalCode': '10028', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1659 1st Ave (btwn E 86th & E 87th St)', 'New York, NY 10028', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/pengs-noodle-folk/579fb23f498e7f9f1b7bd04c', 'categories': [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}}, {'id': '55a59bace4b013909087cb24', 'name': 'Ramen Restaurant', 'pluralName': 'Ramen Restaurants', 'shortName': 'Ramen', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 19}, 'url': 'http://www.pengsnoodlefolk.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 56, 'groups': [{'type': 'others', 'count': 56, 'items': []}], 'summary': '56 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 76, 'delivery': {'id': '333594', 'url': 'https://www.seamless.com/menu/pengs-noodle-folk-1659-1st-ave-new-york/333594?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=333594', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 43, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 43, 'items': [{'id': '57b0ac5e498edc4ef9a3db7a', 'createdAt': 1471196254, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/12536017_YvKA9XeKKoV44AxVaYZy9dnM4bWhnyzSKQ24U9o8YtA.jpg', 'width': 1440, 'height': 1440, 'user': {'id': '12536017', 'firstName': 'dawn.in.newyork', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/12536017-5VTLSXHIFORKXZIY.jpg'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '334629271'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Peng’s Noodle Folk is a family owned restaurant featuring the best homemade noodles and dumplings in NYC.', 'page': {'user': {'id': '334629271', 'firstName': "Peng's Noodle Folk", 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/334629271-NOEVEHRIRHW2IRXX.png'}, 'type': 'venuePage', 'venue': {'id': '579fb23f498e7f9f1b7bd04c'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1470083647, 'tips': {'count': 19, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 19, 'items': [{'id': '59e7817a065ef547f501c199', 'createdAt': 1508344186, 'text': 'Fried pork dum ...
# 4b0dec08f964a520ae5223e3
# {'meta': {'code': 200, 'requestId': '5d90675ea197930038aca511'}, 'response': {'venue': {'id': '4b0dec08f964a520ae5223e3', 'name': 'Alachi Masala', 'contact': {'phone': '2128747420', 'formattedPhone': '(212) 874-7420', 'twitter': 'alachimasala', 'facebook': '833664873419022', 'facebookName': 'Poona Indian Restaurant'}, 'location': {'address': '488 Amsterdam Ave Frnt 1', 'lat': 40.7861663, 'lng': -73.9764143, 'labeledLatLngs': [{'label': 'display', 'lat': 40.7861663, 'lng': -73.9764143}], 'postalCode': '10024', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['488 Amsterdam Ave Frnt 1', 'New York, NY 10024', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/alachi-masala/4b0dec08f964a520ae5223e3', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 17}, 'url': 'http://alachimasalany.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 18, 'groups': [{'type': 'others', 'count': 18, 'items': []}], 'summary': '18 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.7, 'ratingColor': 'C5DE35', 'ratingSignals': 37, 'delivery': {'id': '66495', 'url': 'https://www.seamless.com/menu/alachi-masala-indian-488-amsterdam-ave-new-york/66495?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=66495', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/alachi-masala/4b0dec08f964a520ae5223e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b0dec08f964a520ae5223e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 30, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 30, 'items': [{'id': '564f9f5b498effcbe55c3d2d', 'createdAt': 1448058715, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/146736771_uF-s4Al75_uFr3JBBipYPX0Zq3ljcFQG9N1JIIgSTBU.png', 'width': 406, 'height': 406, 'user': {'id': '146736771', 'firstName': 'Alachi Masala', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/146736771-NPUQCBKPWG0V4JB1.jpg'}, 'type': 'venuePage', 'venue': {'id': '4b0dec08f964a520ae5223e3'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '146736771'}, 'reasons': {'count': 0, 'items': []}, 'description': 'Indian food', 'storeId': '', 'page': {'user': {'id': '146736771', 'firstName': 'Alachi Masala', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/146736771-NPUQCBKPWG0V4JB1.jpg'}, 'type': 'venuePage', 'venue': {'id': '4b0dec08f964a520ae5223e3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1259203592, 'tips': {'count': 17, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 17, 'items': [{'id': '520456f2498e5bedb25fa93a', 'createdAt': 1376016114, 'text': 'The naan is soo good!! The saag aloo is also really really yummy :)', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/520456f2498e5bedb25fa93a', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '7016812', 'firstName': 'Kim', 'lastName': 'Hoedeman', 'ge ...
# 591890f43abcaf1ddca66e85
# {'meta': {'code': 200, 'requestId': '5d90675fdb1d810032207149'}, 'response': {'venue': {'id': '591890f43abcaf1ddca66e85', 'name': 'Ashoka', 'contact': {}, 'location': {'address': '489 Columbus Ave', 'lat': 40.784842463371454, 'lng': -73.97325299421942, 'labeledLatLngs': [{'label': 'display', 'lat': 40.784842463371454, 'lng': -73.97325299421942}], 'postalCode': '10024', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['489 Columbus Ave', 'New York, NY 10024', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/ashoka/591890f43abcaf1ddca66e85', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 9}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 19, 'groups': [{'type': 'others', 'count': 19, 'items': []}], 'summary': '19 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.4, 'ratingColor': '73CF42', 'ratingSignals': 29, 'delivery': {'id': '373820', 'url': 'https://www.seamless.com/menu/ashoka-489-columbus-ave-new-york/373820?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=373820', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 9, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 9, 'items': [{'id': '5b9e7d8ccb3fd2002cf76af3', 'createdAt': 1537113484, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2580387_RXXGleNxMq32m26LzW9Quv4APkOHz9j5E8Kmb_5DcRI.jpg', 'width': 1425, 'height': 1900, 'user': {'id': '2580387', 'firstName': 'Landon', 'lastName': 'Ewers', 'gender': 'male', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2580387_s0Q3tYY8_yPcIIxEjgJfBSio-Ac3oyB9mxY6PHTK_biyjHrYGnS3U_xEYKh9d-N2lXEYF_7Kg.jpg'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1494782196, 'tips': {'count': 9, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 9, 'items': [{'id': '5b99c12b15173e002c679fb0', 'createdAt': 1536803115, 'text': 'Paneer Tikka Marsala is delicious! Good balance of flavor - they offer takeout and free delivery as well!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5b99c12b15173e002c679fb0', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '6476100', 'firstName': 'Stephanie', 'lastName': 'DeDecker', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/6476100_019B-jsI_FGv4U08_h0MOGHWajefzWviuTsH1TjC20ORNJnMJm01dy4dfAWUy7gkKpP6dvDJ5.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2qjKemg', 'timeZone': 'America/New_York', 'listed': {'count': 12, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 12, 'items': [{'id': '5574bb62498e410d565d2892', 'name': 'NYC', 'description': '', 'type': 'others', 'user': {'id': '37772879', 'firstName': 'Cary', 'lastName': 'Lawson', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/37772879-ROH1IHYEPKANUPQM.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/37772879/list/nyc', 'canonicalUrl': 'https://foursquare.com/user/37772879/list/nyc' ...
# 42489a80f964a5208b201fe3
# {'meta': {'code': 200, 'requestId': '5d90675fbe70780039fef456'}, 'response': {'venue': {'id': '42489a80f964a5208b201fe3', 'name': 'Swagat', 'contact': {'phone': '2123621400', 'formattedPhone': '(212) 362-1400', 'twitter': 'swagatny'}, 'location': {'address': '411 Amsterdam Ave', 'crossStreet': 'btwn 80th St & 79th St', 'lat': 40.783573082941615, 'lng': -73.97803042905113, 'labeledLatLngs': [{'label': 'display', 'lat': 40.783573082941615, 'lng': -73.97803042905113}], 'postalCode': '10024', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['411 Amsterdam Ave (btwn 80th St & 79th St)', 'New York, NY 10024', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/swagat/42489a80f964a5208b201fe3', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 38}, 'url': 'https://swagatindianny.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 105, 'groups': [{'type': 'others', 'count': 105, 'items': []}], 'summary': '105 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 154, 'delivery': {'id': '66473', 'url': 'https://www.seamless.com/menu/swagat-indian-cuisine-411a-amsterdam-ave-new-york/66473?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=66473', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/swagat/42489a80f964a5208b201fe3/menu', 'mobileUrl': 'https://foursquare.com/v/42489a80f964a5208b201fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 47, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 47, 'items': [{'id': '592d94a9f343353b97721dc2', 'createdAt': 1496159401, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/418698949_brzTMW1IaPYycAjWmYckNzx2ukd7Xyv4yN8Gz6G88zg.jpg', 'width': 1500, 'height': 1000, 'user': {'id': '418698949', 'firstName': 'Swagat', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/418698949_5Hg55l4d_4nx5ojgNGa5PXdgShaEobaKgR02iJwhuunH14I_vGwMM0FItp0ozPf-ogxLP78Sc.png'}, 'type': 'venuePage', 'venue': {'id': '42489a80f964a5208b201fe3'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '418698949'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'At Swagat, we specialize in northern Indian Cuisine.', 'page': {'user': {'id': '418698949', 'firstName': 'Swagat', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/418698949_5Hg55l4d_4nx5ojgNGa5PXdgShaEobaKgR02iJwhuunH14I_vGwMM0FItp0ozPf-ogxLP78Sc.png'}, 'type': 'venuePage', 'venue': {'id': '42489a80f964a5208b201fe3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1112054400, 'tips': {'count': 38, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 38, 'items': [{'id': '5093306be4b0c441553cdc60', 'createdAt': 1351823467, 'text': 'delicious food! chicken tikka masala + garlic naan.', 'type': 'user', 'canonicalUrl': 'https://fo ...
# 573133a7498e5a92b8615cfd
# {'meta': {'code': 200, 'requestId': '5d90675fd69ed00039d65d56'}, 'response': {'venue': {'id': '573133a7498e5a92b8615cfd', 'name': 'Flame', 'contact': {'phone': '6468700301', 'formattedPhone': '(646) 870-0301', 'twitter': 'flame_nyc'}, 'location': {'address': '100 W 82nd St', 'crossStreet': 'Columbus Ave', 'lat': 40.78412042372414, 'lng': -73.97453725869005, 'labeledLatLngs': [{'label': 'display', 'lat': 40.78412042372414, 'lng': -73.97453725869005}], 'postalCode': '10024', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['100 W 82nd St (Columbus Ave)', 'New York, NY 10024', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/flame/573133a7498e5a92b8615cfd', 'categories': [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d111941735', 'name': 'Japanese Restaurant', 'pluralName': 'Japanese Restaurants', 'shortName': 'Japanese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 18}, 'url': 'http://flamenyc.com', 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'likes': {'count': 65, 'groups': [{'type': 'others', 'count': 65, 'items': []}], 'summary': '65 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.9, 'ratingColor': 'C5DE35', 'ratingSignals': 90, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 74, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 74, 'items': [{'id': '5a7ccb37b4dc6c527f15e538', 'createdAt': 1518127927, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/474466530_8bPDmNyxqYPPsHYMu-Fwe-H8sU6pTF5rLwZhx6AWQjw.jpg', 'width': 1500, 'height': 1000, 'user': {'id': '474466530', 'firstName': 'Flame', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/474466530_n5UmoFra_QeV6O0yQ8q14ZIYSdtdF36AFI9zJDwPCWJlXSUBBcQPUWVjy43n9dRk8hfwRhFBD.png'}, 'type': 'venuePage', 'venue': {'id': '573133a7498e5a92b8615cfd'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '474466530'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': "Located on New York's Upper West Side, Flame specializes in serving hibachi, sushi, and a variety of other vibrant Asian dishes.", 'page': {'user': {'id': '474466530', 'firstName': 'Flame', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/474466530_n5UmoFra_QeV6O0yQ8q14ZIYSdtdF36AFI9zJDwPCWJlXSUBBcQPUWVjy43n9dRk8hfwRhFBD.png'}, 'type': 'venuePage', 'venue': {'id': '573133a7498e5a92b8615cfd'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1462842279, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '5d06945a0fe7a0002caec0ea', 'createdAt': 1560712282, 'text': 'Not fine dining by any means, but a lot of fun and good for a group. Tasty food and very friendly staff.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d06945a0fe7a0002caec0ea', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, ' ...
# 49d91c12f964a520015e1fe3
# ...
# 59723de1033693233be0f8fe
# {'meta': {'code': 200, 'requestId': '5d906767598e64002cdc63fc'}, 'response': {'venue': {'id': '59723de1033693233be0f8fe', 'name': 'Mighty Bowl', 'contact': {}, 'location': {'address': '2nd Ave', 'crossStreet': 'Btw 43rd & 44th St', 'lat': 40.75096979898272, 'lng': -73.97145558640254, 'labeledLatLngs': [{'label': 'display', 'lat': 40.75096979898272, 'lng': -73.97145558640254}], 'postalCode': '10017', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2nd Ave (Btw 43rd & 44th St)', 'New York, NY 10017', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/mighty-bowl/59723de1033693233be0f8fe', 'categories': [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 0}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 29, 'groups': [{'type': 'others', 'count': 29, 'items': []}], 'summary': '29 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 35, 'delivery': {'id': '716491', 'url': 'https://www.seamless.com/menu/mighty-bowl-817-2nd-ave-new-york/716491?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=716491', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 12, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 12, 'items': [{'id': '5c15fa148c812a003948b7ce', 'createdAt': 1544944148, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1440615__xlnYQreHE4szAOHmn6nF1RgU9pOGuZ1r3h3N58eazc.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '1440615', 'firstName': 'KreuZ', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/-ZEWS4F5GIW4S2RXH.jpg'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1500659169, 'tips': {'count': 0, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 0, 'items': []}]}, 'shortUrl': 'http://4sq.com/2tnEmcq', 'timeZone': 'America/New_York', 'listed': {'count': 12, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 12, 'items': [{'id': '5afaef5d7dc9e16716141b20', 'name': 'NYC Filipino Restaurant Week 2018', 'description': '', 'type': 'others', 'user': {'id': '20710801', 'firstName': '████████████████████████████████████████████████████████████████████████████████████████████████████', 'lastName': '████████████████████████████████████████████████████████████████████████████████████████████████████', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/20710801_ERt9QcVF_d4shX-sTA1YKvd5a7eFvICfYOkBmsDMKRfRyA4h4Io7_LK36jFYqeuJU5lbdQCfP.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/20710801/list/nyc-filipino-restaurant-week-2018', 'canonicalUrl': 'https://foursquare.com/user/20710801/list/nyc-filipino-restaurant-week-2018', 'createdAt': 1526394717, 'updatedAt': 1526394815, 'photo': {'id': '50107956e4b088a2335f66c6', 'createdAt': 1343256918, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/Hd5aT5fm9sqaFhBWrT6EOxzNbu2SrMJvmZmv-SuaVlM.jpg', 'width': 540, 'height': 540, 'user': {'id': '16969257', 'firstName': 'Lillycita', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/use ...
# 52a1fa08498ede15b1530912
# {'meta': {'code': 200, 'requestId': '5d906767cf72a0002c48a970'}, 'response': {'venue': {'id': '52a1fa08498ede15b1530912', 'name': 'Deep Indian Kitchen (Indikitch)', 'contact': {'phone': '6465907152', 'formattedPhone': '(646) 590-7152', 'twitter': 'indikitch', 'instagram': 'deepindiankitchen_restaurant'}, 'location': {'address': '25 W 23rd St', 'crossStreet': 'btwn 5th & 6th Ave', 'lat': 40.742025061405144, 'lng': -73.99055792757031, 'labeledLatLngs': [{'label': 'display', 'lat': 40.742025061405144, 'lng': -73.99055792757031}], 'postalCode': '10010', 'cc': 'US', 'neighborhood': 'NoMad', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['25 W 23rd St (btwn 5th & 6th Ave)', 'New York, NY 10010', 'United States']}, 'canonicalUrl': 'https://foursquare.com/indikitch', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 129}, 'url': 'https://www.deepfoods.com', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 679, 'groups': [{'type': 'others', 'count': 679, 'items': []}], 'summary': '679 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 906, 'delivery': {'id': '301591', 'url': 'https://www.seamless.com/menu/indikitch-25-w-23rd-st-new-york/301591?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=301591', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://www.deepfoods.com/assets/menu/Deep%20Foods%20Menu.pdf', 'mobileUrl': 'https://www.deepfoods.com/assets/menu/Deep%20Foods%20Menu.pdf', 'externalUrl': 'https://www.deepfoods.com/assets/menu/Deep%20Foods%20Menu.pdf'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 275, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 275, 'items': [{'id': '52f10fe311d254b8a3254d9c', 'createdAt': 1391529955, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/73155260_cPViYcuaK6rF3-m1S4-K8nMAPkt4XkqkmSXPIDHqtt0.jpg', 'width': 800, 'height': 534, 'user': {'id': '73155260', 'firstName': 'Deep Indian Kitchen (Indikitch)', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/73155260-PYVTCBSGK45WAC4T.png'}, 'type': 'venuePage', 'venue': {'id': '52a1fa08498ede15b1530912'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'venuePage': {'id': '73155260'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'page': {'user': {'id': '73155260', 'firstName': 'Deep Indian Kitchen (Indikitch)', 'gender': 'none', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/73155260-PYVTCBSGK45WAC4T.png'}, 'type': 'venuePage', 'venue': {'id': '52a1fa08498ede15b1530912'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'homeCity': 'New York, NY', 'bio': '', 'contact': {'twitter': 'indikitch'}}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1386347016, 'tips': {'count': 129, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 129, 'items': [{'id': '5310d2fc11d2929c667deb83', 'createdAt': 1393611516, 'text': 'Get the pulled pork feast, onion bhaji, mango lassi, then take a nap.', 'type': 'user', 'canonicalUrl': 'https://fo ...
# 5c8736c0178a2a002cf4adce
# {'meta': {'code': 200, 'requestId': '5d9067678ad62e0039647ba3'}, 'response': {'venue': {'id': '5c8736c0178a2a002cf4adce', 'name': 'Kawi', 'contact': {}, 'location': {'address': '20 Hudson Yards', 'lat': 40.75391341242933, 'lng': -74.00132164772553, 'labeledLatLngs': [{'label': 'display', 'lat': 40.75391341242933, 'lng': -74.00132164772553}], 'postalCode': '10001', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['20 Hudson Yards', 'New York, NY 10001', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/kawi/5c8736c0178a2a002cf4adce', 'categories': [{'id': '4bf58dd8d48988d142941735', 'name': 'Asian Restaurant', 'pluralName': 'Asian Restaurants', 'shortName': 'Asian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 11}, 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 55, 'groups': [{'type': 'others', 'count': 55, 'items': []}], 'summary': '55 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 61, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/kawi/5c8736c0178a2a002cf4adce/menu', 'mobileUrl': 'https://foursquare.com/v/5c8736c0178a2a002cf4adce/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 85, 'groups': [{'type': 'checkin', 'name': "Friends' check-in photos", 'count': 0, 'items': []}, {'type': 'venue', 'name': 'Venue photos', 'count': 85, 'items': [{'id': '5d8404bc72b2a10008edf98d', 'createdAt': 1568933052, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4922410_6Dyq58avUt6x6PbBVApc4aznbtsUlvUX_51FQRruQTs.jpg', 'width': 1440, 'height': 1440, 'user': {'id': '4922410', 'firstName': 'Judy', 'lastName': 'Vincent', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4922410_CAfLZYEa_TiqNnKhYng7rtEZ9aonxYiaL-TxhQuQx9sPpsHVQu6GFC3Pg8AdASpWM3ssOKuSv.jpg'}}, 'visibility': 'public'}]}], 'summary': '0 photos'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1552365248, 'tips': {'count': 11, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 11, 'items': [{'id': '5d7e9674a22db80006000d03', 'createdAt': 1568577140, 'text': 'i prefer the large plates to the small. yesterday’s stinky stew is ugly delicious. the crab special is not always available and sells out early - get it if you can.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d7e9674a22db80006000d03', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '351064', 'firstName': 'katie', 'lastName': '🍔', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/PXQNJRP3YPLCJYUS.jpg'}}}]}]}, 'shortUrl': 'https://4sq.com/2Ht3AQH', 'timeZone': 'America/New_York', 'listed': {'count': 137, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 137, 'items': [{'id': '4ff8646de4b0903668bec9b3', 'name': "Manhattan To-Do's (Between Houston & 34th Street)", 'description': '', 'type': 'others', 'user': {'id': '66672', 'firstName': 'Rachel', 'lastName': 'W.', 'gender': 'female', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/66672_nmeKCbUn_JPON_UQUSVA_1yiG-U6aTgyH88SWg8DUOGgwYQ00b9V36VwAKZaD5bo8BpAZpAFh.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/relevantrachel/list/manhattan-todos-between-houston--34th-street', 'canonicalUrl': 'https://foursquare.com/rel ...
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
manhattan_indian_restaurant[['Rating','Id']]
# Out:
#       Rating                        Id
# 54       8.5  4b89ac72f964a520e94a32e3
# 66       9.2  574f2ae0498ec2a700651b95
# 149      7.8  4ae7876ef964a5201eac21e3
# 294      7.6  54c2bd96498eaf5142e3fe92
# 312      7.4  5914ff32b23dfa207eca38de
# 338      8.0  529d382a11d2dd5ef107e641
# 565      8.3  579fb23f498e7f9f1b7bd04c
# 822      7.7  4b0dec08f964a520ae5223e3
# 850      8.4  591890f43abcaf1ddca66e85
# 863      8.3  42489a80f964a5208b201fe3
# 882      7.9  573133a7498e5a92b8615cfd
# 1169     8.8  49d91c12f964a520015e1fe3
# 1175     8.5  5953e40462420b044e8989f4
# 1289     8.8  4b4aab62f964a520978c26e3
# 1290     8.7  523c7e56498ef9332c5ce675
# 1442     8.3  56c931b2cd10407d3ecbefda
# 1463     8.8  4593ed04f964a52050401fe3
# 1477     8.7  4d992c1e942ba093ebb5968c
# 1634     7.5  58fd583435f9834464820ba6
# 1671     9.0  4bbb9dbded7776b0e1ad3e51
# 2070     7.6  4d24b812836f5481518645f7
# 2080     7.4  50881852e4b0e8252a73aa1e
# 2093     7.9  424de080f964a520ae201fe3
# 2146     6.2  41575800f964a5202e1d1fe3
# 2398     8.2  5b770657c0cacb002c89bc63
# 2530     7.7  56ed855a498ef3bb022352c3
# 2542     7.5  5b0c8e2d2f97ec002c67a428
# 2608     8.8  5a1e961c1987ec47beed877d
# 2611     8.7  5744f4ad498e346b596e9fa3
# 2637     9.3  591b9e948496ca6e22cdd3f6
# 2689     8.7  51df85c9498edb5ea3ad2e2a
# 2694     8.4  575dea4c498e2739e43a27e2
# 2865     8.3  4a63bfb4f964a520b3c51fe3
# 2867     8.2  52645b7511d282d559770c2d
# 2905     8.4  4fe4fb50c2eee335e4fea69d
# 2921     7.6  3fd66200f964a52099e91ee3
# 3017     8.0  4a5b660df964a52015bb1fe3
# 3021     7.6  59723de1033693233be0f8fe
# 3027     8.3  5ac3984ae57ca64be4dc6168
# 3039     7.6  49e67b55f964a52050641fe3
# 3041     8.0  5ceea403270ee7002ce9199a
# 3064     7.7  540b8829498ef527c96a6973
# 3106     7.6  59723de1033693233be0f8fe
# 3229     8.5  52a1fa08498ede15b1530912
# 3259     8.9  5c8736c0178a2a002cf4adce

# %% [markdown]
# ## Now Cluster the Restaurant on their Rating

# %% [markdown]
# Run *k*-means to cluster the neighborhood into 3 clusters.

# %%
# set number of clusters
kclusters = 3

manhattan_indian_restaurant_clustering = manhattan_indian_restaurant['Rating']


# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_indian_restaurant_clustering.values.reshape(-1,1))

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 2, 2, 2, 2, 1, 2, 1, 1], dtype=int32)

# %% [markdown]
# Let's insert the cluster column along with their respective restaurant in the manhattan_indian_restaurant.

# %%
manhattan_indian_restaurant.insert(0, 'Cluster Labels', kmeans.labels_)

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_indian_restaurant['Neighborhood Latitude'], manhattan_indian_restaurant['Neighborhood Longitude'], manhattan_indian_restaurant['Neighborhood'], manhattan_indian_restaurant['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Result

# %% [markdown]
# The results from k-means clustering show that we can categorize New York neighborhoods into 3 clusters based on how many Indian and Asain restaurants are in each neighborhood:
# * Cluster 0: Restaurants having rating less than 7
# * Cluster 1: Restaurants having rating between  7 and 8
# * Cluster 2:Restaurants having rating greater than 8
#
# The results are visualized in the above map with Cluster 0 in red color, Cluster 1 in light green color and Cluster 2 in light green color.

# %% [markdown]
# ## Recommendations
# Most of Indian and Asian restaurants are in Cluster 0 and 1 which is around Manhattan Valley area have lowest rating on foursquare. So, there is a good opportunity to open near this area as the competition seems to be low.Therefore, this project recommends to open an authentic Indian restaurant in these locations with little to no competition. Nonetheless, if the food is authentic, affordable and good taste, I am confident that it will have great following everywhere.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this project, we have gone through the process of identifying the business problem, specifying the data required, extracting and preparing the data, performing the machine learning by utilizing k-means clustering and providing a recommendation to the stakeholder.
